# %%
folder_path = "/Workspace/Users/amrita.helwade@bizmetric.com/Databricks_DE_Code_Data/"

dbutils.notebook.run("/Workspace/Users/amrita.helwade@bizmetric.com/Databricks_DE_Code_Data/02_schema",
    timeout_seconds=300,
    arguments={"file_path": folder_path})

# %%
dbutils.notebook.run(
"02_schema",
300,
{
"folder_path": "Databricks_DE_Code_Data",
"file_type": "csv",
"load_type": "incremental"
}
)

# %%
dbutils.widgets.getAll()
