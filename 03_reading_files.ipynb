# %%
df = spark.read.csv('/Volumes/bizmetric_databricks_learning/default/sep_2026_training/diabetes.csv', header=True,)

# %%
display(df)

# %%
df1 = spark.read.json("/Volumes/bizmetric_databricks_learning/default/sep_2026_training/F1_project/drivers.json")

# %%
display(df1)

# %%
df = spark.read.format("csv").option("header", True).load("/Volumes/bizmetric_databricks_learning/default/sep_2026_training/diabetes.csv")
