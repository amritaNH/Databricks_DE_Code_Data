# %%
a=10
a

# %%
type(a)

# %%
# %scala
type(spark)

# %%
dir(spark)

# %% [markdown]
# Ctrl+space gives AI suggestions
#
# ## Dataframe creation in spark
# CreateDataFrame accepts data, schema,

# %%
ab.

# %%
data1 = [(1,'Nilesh'),(2,'Nita')]
df = spark.createDataFrame(data = data1, )
df

# %%
display(df)

# %%
df.show()

# %%
df = spark.createDataFrame(data = data1, schema= ['num','First_name'])
df

# %%
df.show()

# %%
help(df.printSchema)

# %%
df.printSchema()

# %% [markdown]
# Here the data type comes as by default but we may create different data types based on
#
# pyspark.sql.types
#
# stuct type is used to take the list as a fields

# %%
import pyspark.sql.types 
help(pyspark.sql.types )

# %%
from pyspark.sql.types import *


data = [(1,'Nilesh'),(2,'Nita')]
schema1= StructType([StructField(name = 'num', dataType= IntegerType()),
            StructField(name = 'First_name', dataType= StringType())  ])

df = spark.createDataFrame(data = data, schema = schema1)
df.show()

# %%
help(StructType)
help(StructField)

# %% [markdown]
# Creating dataframe using dictionary

# %%
data = [{'id':1, 'first_name': 'Nisha'},
        {'id':2, 'first_name': 'Nishant'}]

df = spark.createDataFrame(data = data)
df.show()

# %%
#display(data)
type(data)

# %% [markdown]
# READ single csv
# read multiple csv
#
# DataFrameReader object
#
# Before reading the file enable the database file system which is called as DBFS (databricks file system)
#
#
# for csv file every column is with string file

# %%
help(spark.read)

# %%
df = spark.read.csv(path="dbfs:/FileStore/emp1.csv")
display(df)
df.printSchema()

# %%
df = spark.read.csv(path="dbfs:/FileStore/emp1.csv", header = True)
display(df)
df.printSchema()

# %%
df1= spark.read.format('csv').load(path='dbfs:/FileStore/emp1.csv')
display(df1)
df1.printSchema()

# %%
help(spark.read.options)

# %%
df1= spark.read.format('csv').option(key='header',value=True).load(path='dbfs:/FileStore/emp1.csv')
display(df1)
df1.printSchema()

# %% [markdown]
# # reading multiple files

# %%
# passing list of path with different path
df = spark.read.csv(path=["dbfs:/FileStore/emp1.csv", "dbfs:/FileStore/emp2.csv"], header = True)
display(df)
df.printSchema()

# %%
## all files are on the same path and file are having the same schema

### "dbfs:/FileStore/emp1.csv"

df = spark.read.csv(path="dbfs:/FileStore/" , header = True)
display(df)
df.printSchema()

# %%
from pyspark.sql.types import *

schema1 = StructType().add(field= 'id', data_type= IntegerType())\
                        .add(field= 'name', data_type= StringType() )\
                            .add(field= 'gender', data_type= StringType() )\
                                .add(field= 'mobile', data_type= IntegerType() )

# passing list of path with different path
df = spark.read.csv(path=["dbfs:/FileStore/emp1.csv", "dbfs:/FileStore/emp2.csv"], schema = schema1  , header = True)
display(df)
df.printSchema()

# %%
from pyspark.sql.types import *

schema1 = StructType().add(field= 'id', data_type= IntegerType())\
                        .add(field= 'name', data_type= StringType() )\
                            .add(field= 'gender', data_type= StringType() )\
                                .add(field= 'mobile', data_type= IntegerType() )

# passing list of path with different path
df = spark.read.option(key='header', value = True).csv(path =  "dbfs:/FileStore/emp1.csv", schema=schema1 )
display(df)
df.printSchema()

# %% [markdown]
# # writing the dataframe

# %%
from pyspark.sql  import *
help(DataFrameWriter)

# %%
from pyspark.sql  import dataframe
help(dataframe)

# %%
from pyspark.sql  import dataframe
help(dataframe.DataFrame.write)

# %%
### this code is responsible to generate the parquet file and not feasible to generate .csv file may generate more files based on number of partitions
df1.write.csv(path = "dbfs:/temps/emp1", header= True )

# %%
## generate the error if file already exists
df1.write.csv(path = "dbfs:/temps/emp1", header= True ,mode= 'error' )

# %%
df1.write.csv(path = "dbfs:/temps/emp1", header= True ,mode= 'ignore' )

# %%
df1.write.csv(path = "dbfs:/temps/emp1", header= True ,mode= 'overwrite' )

# %%
### reading the same file 

display(spark.read.csv(path = "dbfs:/temps/emp1", header= True ))

# %%
df1.write.csv(path = "dbfs:/temps/emp1", header= True ,mode= 'append' )

# %%
display(spark.read.csv(path = "dbfs:/temps/emp1", header= True ))

# %%
df1.write.option(header =True).csv('/')

# %% [markdown]
# ## JSON reading

# %%
help(spark.read.json)

# %%
df = spark.read.json(path = 'dbfs:/FileStore/emp.json')
df.printSchema()
df.show()

# %%
### multiline dictionary
df = spark.read.json(path = 'dbfs:/FileStore/CA_category_id-1.json',  multiLine = True)
df.printSchema()

# %%
display(df)

# %%
### 
df = spark.read.json(path = 'dbfs:/FileStore/*.json',  multiLine = True)
df.printSchema()
df.show()

# %%
from pyspark.sql. types import *


schema1 = StructType().add(field= 'id', data_type= IntegerType())\
                        .add(field= 'name', data_type= StringType() )\
                            .add(field= 'gender', data_type= StringType() )\
                                .add(field= 'mobile', data_type= IntegerType() )
### 
df = spark.read.json(path = 'dbfs:/FileStore/emp.json', schema = schema1)
df.printSchema()
df.show()

# %%
display(df)

# %%
df.write.json("dbfs:/temps/emp_json_data")

# %%
## read the same files
df_json = spark.read.json("dbfs:/temps/emp_json_data")

# %%
display(df_json)

# %% [markdown]
# # Parquet files

# %%
par_df = spark.read.parquet("dbfs:/FileStore/iris.parquet")
display(par_df)

# %%
par_df.dtypes

# %%
print(par_df.count())

# %%
type(par_df)

# %%
par_df.info()

# %% [markdown]
# #### reading multiple files

# %%
par_df = spark.read.parquet("dbfs:/FileStore/*.parquet")
display(par_df)

# %%
par_df.show(n=par_df.count(), truncate=4)

# %% [markdown]
# #### Write a parquet file

# %%
df.write.parquet('dbfs:/temps/parquet_folder')

# %%
read_par_df = spark.read.parquet('dbfs:/temps/parquet_folder')
read_par_df.show()

# %% [markdown]
# df.show() is displaying only 20 characters per cell

# %%
df.show(truncate= False)
df.show(truncate =8)
df.show(n=3)
df.show(n=3, truncate = False, vertical = True)
